# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahanas2003/gen_ai/blob/main/generative_adversarial_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 42.4MB/s]

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
adversarial_loss = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
        real_images = batch[0].to(device)

        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)

        real_images = real_images.to(device)

        optimizer_D.zero_grad()

        z = torch.randn(real_images.size(0), latent_dim, device=device)

        fake_images = generator(z)

        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        optimizer_G.zero_grad()

        gen_images = generator(z)

        g_loss = adversarial_loss(discriminator(gen_images), valid)

        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.4678 Generator Loss: 1.2475
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.5974 Generator Loss: 0.9875
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.7417 Generator Loss: 0.9784
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.6196 Generator Loss: 1.2409
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.5419 Generator Loss: 1.6374
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6410 Generator Loss: 1.0223
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.6272 Generator Loss: 1.0396
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.7593 Generator Loss: 0.9955
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6520 Generator Loss: 1.0399
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.5467 Generator Loss: 1.1667
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6804 Generator Loss: 1.1555
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.5551 Generator Loss: 0.9394
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.6082 Generator Loss: 1.1963
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.5193 Generator Loss: 1.3542
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.5654 Generator Loss: 0.7881
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.5606 Generator Loss: 1.4381
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.7622 Generator Loss: 0.7559
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6303 Generator Loss: 1.0735
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.5392 Generator Loss: 1.5942
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.9539 Generator Loss: 0.7461
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.5020 Generator Loss: 1.1090
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.6510 Generator Loss: 1.1289
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.6287 Generator Loss: 0.8426
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.7607 Generator Loss: 0.9559
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.4745 Generator Loss: 1.3123
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.5922 Generator Loss: 0.9905
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.5582 Generator Loss: 0.8863
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.4543 Generator Loss: 1.1841
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5415 Generator Loss: 1.1751
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.5509 Generator Loss: 1.2367
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5740 Generator Loss: 1.3198
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.4283 Generator Loss: 1.3187
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.5053 Generator Loss: 1.4617
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.6508 Generator Loss: 0.8184
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.5515 Generator Loss: 1.0427
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.4331 Generator Loss: 1.5925
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.8231 Generator Loss: 2.3291
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.7782 Generator Loss: 1.0503
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5147 Generator Loss: 1.3390
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.4886 Generator Loss: 1.1824
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.7708 Generator Loss: 0.8359
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.6881 Generator Loss: 0.9347
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.8364 Generator Loss: 1.1501
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.6394 Generator Loss: 1.1694
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.5589 Generator Loss: 2.1409
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.5501 Generator Loss: 1.5290
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.6539 Generator Loss: 1.2858
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.7730 Generator Loss: 1.1183
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.4887 Generator Loss: 1.6373
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.5623 Generator Loss: 1.5388
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.4748 Generator Loss: 1.0930
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.6294 Generator Loss: 1.1150
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.5130 Generator Loss: 1.7685
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6561 Generator Loss: 1.8578
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.7758 Generator Loss: 0.9657
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.5895 Generator Loss: 2.7314
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.6386 Generator Loss: 1.1142
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.4761 Generator Loss: 1.0099
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.4371 Generator Loss: 1.2845
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.7557 Generator Loss: 1.2705
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.5899 Generator Loss: 1.0247
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.5201 Generator Loss: 1.1253
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.7014 Generator Loss: 0.9633
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.5695 Generator Loss: 0.7022
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.5029 Generator Loss: 1.1578
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.6639 Generator Loss: 0.9458
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.7435 Generator Loss: 1.2018
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.5511 Generator Loss: 1.4536
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.5818 Generator Loss: 1.4224
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.5866 Generator Loss: 1.1238
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.5327 Generator Loss: 1.0830
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.5598 Generator Loss: 1.4651
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.6016 Generator Loss: 0.8418
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.4122 Generator Loss: 1.3832
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.3677 Generator Loss: 1.9361
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.8870 Generator Loss: 0.8522
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.4618 Generator Loss: 1.5472
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.6075 Generator Loss: 1.6087
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.7376 Generator Loss: 1.4705
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.6398 Generator Loss: 1.2230
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.5110 Generator Loss: 1.2236
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.7731 Generator Loss: 0.6067
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.7556 Generator Loss: 0.8669
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.6292 Generator Loss: 1.0774
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.9807 Generator Loss: 1.0250
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.5727 Generator Loss: 1.9867
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.6685 Generator Loss: 0.9633
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.5659 Generator Loss: 1.1065
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.5535 Generator Loss: 1.6705
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.4996 Generator Loss: 1.3606
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.5255 Generator Loss: 0.9564
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.6952 Generator Loss: 1.1346
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.5187 Generator Loss: 1.7621
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.6505 Generator Loss: 1.4353
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.4048 Generator Loss: 1.3046
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.9292 Generator Loss: 0.8623
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.8307 Generator Loss: 1.5306
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.4670 Generator Loss: 1.2452
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.6187 Generator Loss: 0.7646
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.4349 Generator Loss: 1.1834
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.8729 Generator Loss: 0.9949
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.8327 Generator Loss: 0.8826
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.6296 Generator Loss: 1.2071
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.6675 Generator Loss: 0.8728
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.7071 Generator Loss: 1.2821
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.4549 Generator Loss: 0.8552
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.5920 Generator Loss: 1.1168
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.8925 Generator Loss: 0.9643
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.6912 Generator Loss: 0.9429
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.4387 Generator Loss: 1.6665
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.6791 Generator Loss: 1.1159
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.4518 Generator Loss: 0.9923
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.6365 Generator Loss: 0.9268
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.5597 Generator Loss: 1.0539
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.8965 Generator Loss: 0.8433
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.3515 Generator Loss: 1.6539
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.4176 Generator Loss: 1.6646
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.6200 Generator Loss: 1.2671
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.7664 Generator Loss: 1.2654
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.6277 Generator Loss: 1.0411
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.6442 Generator Loss: 1.1235
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.7178 Generator Loss: 1.8580
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.4550 Generator Loss: 1.8117
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.6318 Generator Loss: 1.1159
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.5947 Generator Loss: 1.7105
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.4702 Generator Loss: 1.3702
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.5592 Generator Loss: 1.2704
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.7993 Generator Loss: 1.0249
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.4509 Generator Loss: 1.3468
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.3504 Generator Loss: 1.7534
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.6615 Generator Loss: 1.7354
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.5429 Generator Loss: 1.4152
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.6009 Generator Loss: 2.2180
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.5341 Generator Loss: 1.5931
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.5705 Generator Loss: 1.7424
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.6815 Generator Loss: 1.6518
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.6606 Generator Loss: 1.3659
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.5177 Generator Loss: 1.1519
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.5369 Generator Loss: 1.0411
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.5651 Generator Loss: 1.2718
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.4268 Generator Loss: 1.7510
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.5608 Generator Loss: 1.1122
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.6097 Generator Loss: 1.1233
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.6381 Generator Loss: 0.9113
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.5069 Generator Loss: 1.2866
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.7095 Generator Loss: 1.4283
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.4989 Generator Loss: 1.1124
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.4032 Generator Loss: 1.5194
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.5208 Generator Loss: 1.2611
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.6234 Generator Loss: 0.9427
